# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
print(document_tree)

# %%
# print names of all countries
for child in document_tree.getroot():
    print (child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
print(document_tree.getroot())
# Out:
# <Element 'mondial' at 0x10420ab38>

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print ('* ' + element.find('name').text + ':',)
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print (capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %%
# print names of all countries and their cities
capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string = '' += subelement.find('name').text + ', '
    print (capitals_string = ''[:-2])
# Out:
#   File "<ipython-input-33-de9908038b3f>", line 3
#     for subelement in element.getiterator('city'):
#     ^
# IndentationError: unexpected indent

# %%
a''
for element in document_tree.iterfind('country'):
    print ('* ' + element.find('name').text + ':',)
    #capitals_string = ''#
# Out:
#   File "<ipython-input-31-6eac83767d52>", line 1
#     a''
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
document.tag
# Out:
# 'mondial'

# %%
for child in document.getroot():
    print (child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra
# France
# Spain
# Austria
# Czech Republic
# Germany
# Hungary
# Italy
# Liechtenstein
# Slovakia
# Slovenia
# Switzerland
# Belarus
# Latvia
# Lithuania
# Poland
# Ukraine
# Russia
# Belgium
# Luxembourg
# Netherlands
# Bosnia and Herzegovina
# Croatia
# Bulgaria
# Romania
# Turkey
# Denmark
# Estonia
# Faroe Islands
# Finland
# Norway
# Sweden
# Monaco
# Gibraltar
# Guernsey
# Holy See
# Ceuta
# Melilla
# Iceland
# Ireland
# San Marino
# Jersey
# Malta
# Isle of Man
# Moldova
# Portugal
# Svalbard
# United Kingdom
# Afghanistan
# China
# Iran
# Pakistan
# Tajikistan
# Turkmenistan
# Uzbekistan
# Armenia
# Georgia
# Azerbaijan
# Bahrain
# Bangladesh
# Myanmar
# India
# Bhutan
# Brunei
# Malaysia
# Laos
# Thailand
# Cambodia
# Vietnam
# Kazakhstan
# North Korea
# Kyrgyzstan
# Hong Kong
# Macao
# Mongolia
# Nepal
# Christmas Island
# Cocos Islands
# Cyprus
# Gaza Strip
# Israel
# Egypt
# Indonesia
# Timor-Leste
# ...

# %%
for country in document.findall('country'):
     rate = country.find('infant_mortality').text
     name = country.get('name')
     print (name, rate)
# Out:
# None 13.19
# None 4.78
# None 7.9
# None 6.16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-b9f1e13e409e> in <module>()
#       1 for country in document.findall('country'):
# ----> 2      rate = country.find('infant_mortality').text
#       3      name = country.get('name')
#       4      print (name, rate)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for element in document.iterfind('country'):
    print (element.find('infant_mortality').text)
# Out:
# 13.19
# 4.78
# 7.9
# 6.16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-1a4037e59f1e> in <module>()
#       1 for element in document.iterfind('country'):
# ----> 2     print (element.find('infant_mortality').text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for child in document:
    print (child.find('name').text, .get('infant_mortality'))
# Out:
# Albania None
# Greece None
# Macedonia None
# Serbia None
# Montenegro None
# Kosovo None
# Andorra None
# France None
# Spain None
# Austria None
# Czech Republic None
# Germany None
# Hungary None
# Italy None
# Liechtenstein None
# Slovakia None
# Slovenia None
# Switzerland None
# Belarus None
# Latvia None
# Lithuania None
# Poland None
# Ukraine None
# Russia None
# Belgium None
# Luxembourg None
# Netherlands None
# Bosnia and Herzegovina None
# Croatia None
# Bulgaria None
# Romania None
# Turkey None
# Denmark None
# Estonia None
# Faroe Islands None
# Finland None
# Norway None
# Sweden None
# Monaco None
# Gibraltar None
# Guernsey None
# Holy See None
# Ceuta None
# Melilla None
# Iceland None
# Ireland None
# San Marino None
# Jersey None
# Malta None
# Isle of Man None
# Moldova None
# Portugal None
# Svalbard None
# United Kingdom None
# Afghanistan None
# China None
# Iran None
# Pakistan None
# Tajikistan None
# Turkmenistan None
# Uzbekistan None
# Armenia None
# ...

# %%
for element in document.iterfind('country'):
    print (element.name + ':' + element.infant_mortality)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-4a57b6a8702e> in <module>()
#       1 for element in document.iterfind('country'):
# ----> 2     print (element.name + ':' + element.infant_mortality)
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'name'

# %%
for country in document.iter('country'):
    print (country.infant_mortality, country.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-91be9aee6874> in <module>()
#       1 for country in document.iter('country'):
# ----> 2     print (country.infant_mortality, country.name)
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'infant_mortality'

# %%
document.findall("./country/name")
# Out:
# [<Element 'name' at 0x106277098>,
#  <Element 'name' at 0x106253908>,
#  <Element 'name' at 0x106258098>,
#  <Element 'name' at 0x10624e2c8>,
#  <Element 'name' at 0x107f727c8>,
#  <Element 'name' at 0x107f6e688>,
#  <Element 'name' at 0x107f68ef8>,
#  <Element 'name' at 0x107f68138>,
#  <Element 'name' at 0x107a6d318>,
#  <Element 'name' at 0x107837e58>,
#  <Element 'name' at 0x107816f98>,
#  <Element 'name' at 0x10780aa98>,
#  <Element 'name' at 0x106405ea8>,
#  <Element 'name' at 0x107ee1ae8>,
#  <Element 'name' at 0x1078afb88>,
#  <Element 'name' at 0x107892048>,
#  <Element 'name' at 0x1078a1638>,
#  <Element 'name' at 0x1078996d8>,
#  <Element 'name' at 0x107875c28>,
#  <Element 'name' at 0x1078624a8>,
#  <Element 'name' at 0x107859bd8>,
#  <Element 'name' at 0x1078535e8>,
#  <Element 'name' at 0x107adee58>,
#  <Element 'name' at 0x107966048>,
#  <Element 'name' at 0x1075c5c28>,
#  <Element 'name' at 0x106eaa598>,
#  <Element 'name' at 0x106ea35e8>,
# ...

# %%
 for country in document.findall('country'):
    name = (country.find('name').text)
  #  rate = int((country.find('rank').text))#
print(name)
# Out:
# Seychelles

# %%
for child in document.getroot():
    print ((child.find('name').text), str(child.find('infant_mortality').text))
# Out:
# Albania 13.19
# Greece 4.78
# Macedonia 7.9
# Serbia 6.16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-40e6188cd5e6> in <module>()
#       1 for child in document.getroot():
# ----> 2     print ((child.find('name').text), str(child.find('infant_mortality').text))
#       3
#
# AttributeError: 'NoneType' object has no attribute 'text'
